# %%
from sts.mktdata.ticker import Ticker
# Out:
# Traceback (most recent call last):
#
#   File ~/venv/pydev/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from sts.mktdata.ticker import Ticker
#
#   File ~/repos/systrading/sts/mktdata/ticker.py:1
#     from ..utils.cfg_parser import get_cfg
#
#   File ~/repos/systrading/sts/utils/__init__.py:3
#     import .fn as fn
#            ^
# SyntaxError: invalid syntax

# %%
ticker = Ticker('us/etf.yml')
