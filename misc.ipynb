# %%
from sts.utils import configParser
from sts.data.ticker import Ticker

# %%
config = configParser('us/stock.yml')

# %%
config['industry']
# Out:
# '/data/stsdata/us/stocks/industry'

# %%
ticker = Ticker('us/stock.yml')

# %%
symbol_industry =  ticker.symbol_industry(symbols = ['AAPL', 'MSFT', 'GOOGL'])

# %%
symbol_industry
# Out:
#   symbol                                name     marketCap        country  \
# 0   AAPL             Apple Inc. Common Stock  3.979470e+12  United States
# 1  GOOGL  Alphabet Inc. Class A Common Stock  4.166207e+12  United States
# 2   MSFT  Microsoft Corporation Common Stock  3.153071e+12  United States
#
#    ipoYear    volume      sector  \
# 0   1980.0  38123484  Technology
# 1   2004.0  26397331  Technology
# 2   1986.0  27409972  Technology
#
#                                          industry       asof
# 0                          Computer Manufacturing 2026-04-25
# 1  Computer Software: Programming Data Processing 2026-04-25
# 2         Computer Software: Prepackaged Software 2026-04-25
