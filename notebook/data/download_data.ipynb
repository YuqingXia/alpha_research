# %%
from sts.dio.symbols import sp500_symbol_table
from sts.dio.equity import Ticker, TickerDataMode

# %%
data_folder = '/home/yuqing42/projects/systrading/data/Equity/'

# %%
for sym in sp500_symbol_table.to_symbol():
    print(sym, end = ', ')
    ticker = Ticker(sym.YahooSym)
    break
    ticker.set_data
    ohlc = ticker.history(period = '10y', )
# Out:
# MMM,

# %%
ticker.set_data_mode(TickerDataMode.)
# Out:
#   Cell In[6], line 1
#     ticker.set_data_mode(TickerDataMode.)
#                                         ^
# SyntaxError: invalid syntax

# %%
TickerDataMode.
# Out:
# <enum 'TickerDataMode'>

# %%
131.8/1.18
# Out:
# 111.6949152542373

# %%
134/
