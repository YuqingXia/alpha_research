# %% [markdown]
# ### Simple backtest with account curves

# %%
from sts.data import yh_data
from sts.systems.accounts.curves.account_curve import accountCurve
from sts.systems.accounts.pandl_calculators.pandl_calculation import pandlCalculation

# %%
ETF_list = ["XLE", "XLF", "XLU", "XLI", "XLK", "XLV", "XLY", "XLP", "XLB", "IYR", "TLT"]
sym_table = yh_data.symbol_table.query('AssetClass == "ETF"')
sym_table = sym_table[sym_table.Symbol.isin(ETF_list)]

# %%
yh_data
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Dividends',
#  'Stock Splits',
#  'Capital Gains']

# %%
pandlCalculation(price_ts, positions)
