# %% [markdown]
# ## Maximize correlation

# %% [markdown]
# Predicting factors are hard to find and most of the time we can only follow the market until some abnormal stuffs start happen. To observe such abnormal behaviors, we typically can develop factors to capture different properties of the market to help us understand what is going on. One problem is that we need to optimize which horizon or which threshold to use for such abnormal behavior detection to be effective. So we need an optimization way to help us to find it. This is much easier than purely find alpha. Status detection is also supper important
