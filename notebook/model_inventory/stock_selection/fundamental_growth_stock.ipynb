# %% [markdown]
# A good growth stock should have a up trend revenue as well as EPS. The longer the trend, the safer the stock is as long as no strategic plan change.

# %%
# import library
import sys

sys.path.append("/home/yuqing/project/systrading/src/")
from sts.data.sp500 import sp500_yh_data

# %%
yh_ticker = sp500_yh_data["PWR"]

# %%
df = yh_ticker.history(period="10y")
# Out:
# /home/yuqing/miniconda3/lib/python3.10/site-packages/yfinance/utils.py:681: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
yh_ticker.get_earnings_trend()
