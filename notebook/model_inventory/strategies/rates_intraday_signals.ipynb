# %% [markdown]
# This notebook is a summary about the intraday pattern observed on rates markets

# %% [markdown]
# ### Auctions

# %% [markdown]
# The auction result in general is tail but we should look at recent results to gauge the investor risk appetite. For example, at the eod of hiking cycle, auction result is typically through instead of tail. The other intraday pattern is ouright and curve. Based on the auction result, strong tail typically means a rally later due to the missed buying power and strong throught typically means a selling afternoon due to the dealer need to offload their positions. At curve side, due to dealer need to hedge the position and thus typically trying to off load other sectors which cause a flattening for 30y auction and steepening for fron end auctions.

# %% [markdown]
# 4pm pattern

# %% [markdown]
# intraday strong pattern typically will slightly reverse at or after 4pm at EOD due to the unwind of position. For example a strong rally can typically means a sell of after 4pm (not necessarily at 4pm because that strong rally typically means other ETF flow reblance can push it rally again). but after 4pm,
