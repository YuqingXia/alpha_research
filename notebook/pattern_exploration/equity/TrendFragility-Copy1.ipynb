# %% [markdown]
# ![image](https://macro-ops.com/wp-content/uploads/2024/05/Trend-Fragility-Components-052824-1024x562.jpg)

# %% [markdown]
# In this notebook, we try to replicate the trend fragility mentioned in macro-ops.
