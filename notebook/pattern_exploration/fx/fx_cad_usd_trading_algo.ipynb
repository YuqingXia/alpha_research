# %%
#import packages
from stlib.utils.nbutils import set_notebook_content_width
import pandas as pd
import numpy as np
from zipfile import ZipFile

# %%
set_notebook_content_width(90)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Context

# %% [markdown]
# this notebook is to replicate the work done in the post by [Daniel Shapiro](https://towardsdatascience.com/data-science-in-algorithmic-trading-d21a46d1565d)

# %% [markdown]
# ### Data

# %% [markdown]
# #### CAD_USD Rate Data

# %% [markdown]
# daily exchange rates can be found [here](https://open.canada.ca/data/en/dataset/1bc25b1e-0e02-4a5e-afd7-7b96d6728aac)

# %%
historical_data = '../../data/fx_cad_usd_10100008-eng.zip'
zip_file = ZipFile(historical_data)

# %%
data = {}
for file in zip_file.filelist:
    if file.filename.endswith('csv'):
        data[file.filename] = pd.read_csv(zip_file.open(file.filename))
# Out:
# /home/yuqing42/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data['10100008_MetaData.csv']
# Out:
#                                            Cube Title  \
# 0   Foreign exchange rates in Canadian dollars, Ba...
# 1                                        Dimension ID
# 2                                                   1
# 3                                                   2
# 4                                        Dimension ID
# ..                                                ...
# 70                                            Note ID
# 71                                                  1
# 72                                                  2
# 73                                                  3
# 74                                       Dimension ID
#
#                                            Product Id            CANSIM Id  \
# 0                                            10100008             176-0067
# 1                                      Dimension name      Dimension Notes
# 2                                           Geography                  NaN
# ...

# %%
data['10100008.csv']
# Out:
#           REF_DATE     GEO  DGUID  \
# 0       1950-10-02  Canada    NaN
# 1       1950-10-02  Canada    NaN
# 2       1950-10-02  Canada    NaN
# 3       1950-10-02  Canada    NaN
# 4       1950-10-02  Canada    NaN
# ...            ...     ...    ...
# 534277  2017-04-28  Canada    NaN
# 534278  2017-04-28  Canada    NaN
# 534279  2017-04-28  Canada    NaN
# 534280  2017-04-28  Canada    NaN
# 534281  2017-04-28  Canada    NaN
#
#                                         Type of currency      UOM  UOM_ID  \
# 0                   United States dollar, noon spot rate  Dollars      81
# 1                           Danish krone, noon spot rate  Dollars      81
# 2                        Norwegian krone, noon spot rate  Dollars      81
# 3                          Swedish krona, noon spot rate  Dollars      81
# 4                            Swiss franc, noon spot rate  Dollars      81
# ...                                                  ...      ...     ...
# ...

# %%
20 * 100k
# Out:
#   File "<ipython-input-1-c6ee9ba461b0>", line 1
#     20 * 100k
#             ^
# SyntaxError: invalid syntax
