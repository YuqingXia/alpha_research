# %% [markdown]
# tracking the performance of all SPX sectors and evaluate their relative performance and momentum, define enter and exit points and eveluate backtest performance

# %%
#import packages
import datetime
import yfinance as yf
from __future__ import annotations
from typing import List, Union, Dict

# %%
# configures
looking_back_days = 252
ed = datetime.date(2023, 4, 11)

# %%
#functions
class SPXRotationStrategy(object):
    default_sector_tickers = ['XLE', 'XLF', 'XLU', 'XLI', 'XLK', 'XLV', 'XLY', 'XLP', 'XLB', 'XOP', 'IYR', 'IBB', 'KRE', 'XTL']
    def __init__(self, sector_tickers : List = SPXRotationStrategy.default_sector_tickers, 
                       benchmark_ticker : str = 'SPY'):
        self.sector_tickers = sector_tickers
        self.benchmark_ticker = benchmark_ticker
    
    def
