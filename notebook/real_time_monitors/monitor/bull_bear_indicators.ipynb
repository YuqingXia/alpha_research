# %%
# packages
import pandas as pd

# %%
aaii_sentiment_survey_df = pd.read_csv(
    "/home/yuqing42/projects/stsdata/ecodata/aaii_investor_sentiment_survey.csv",
    header=[0],
)

# %%
aaii_sentiment_survey_df
# Out:
#            Date Bullish Neutral Bearish Total BullishAvg8Week BullBearSpread
# 0     7/17/1987     NaN     NaN     NaN   NaN             NaN            NaN  \
# 1     7/24/1987  36.00%  50.00%  14.00%  100%             NaN         22.00%
# 2     7/31/1987  26.00%  48.00%  26.00%  100%             NaN          0.00%
# 3      8/7/1987  56.00%  15.00%  29.00%  100%             NaN         27.00%
# 4     8/14/1987  45.00%  35.00%  20.00%  100%             NaN         25.00%
# ...         ...     ...     ...     ...   ...             ...            ...
# 1909  2/29/2024  46.50%  32.17%  21.34%  100%          44.91%         25.20%
# 1910   3/7/2024  51.74%  26.50%  21.77%  100%          45.30%         30.00%
# 1911  3/14/2024  45.90%  32.22%  21.88%  100%          45.99%         24.00%
# 1912  3/21/2024  43.20%  29.61%  27.19%  100%          46.48%         16.00%
# 1913  3/28/2024  50.00%  27.55%  22.45%  100%          46.60%         27.60%
#
# ...
