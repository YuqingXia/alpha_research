# %%
from sts.data.yahoo.yhdata import YHData
from sts.data.database import symbol_table_fn
import datetime

# %%
symbol_table = symbol_table_fn(YahooSym="QQQ", AssetClass="Equity", Symbol="QQQ", Description="QQQ")

# %%
yhdata = YHData(symbol_table)

# %%
ticker = yhdata["QQQ"]

# %%
df = ticker.history(period="3y")
