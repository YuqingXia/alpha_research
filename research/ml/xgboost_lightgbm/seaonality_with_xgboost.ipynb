# %%
import pandas as pd
from sts.data.ticker import Ticker
from sts.quant.candle import Candle
from sts

# %%
ticker = Ticker('us/equity.yml')

# %%
df = ticker.history('AAPL', '20250101', '20251010')

# %%
df = df.set_index('ts')

# %%
Candle(df).plot()
# Out:
# <div>                            <div id="da0f4759-cc28-4262-823d-a621f41d77c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da0f4759-cc28-4262-823d-a621f41d77c1")) {                    Plotly.newPlot(                        "da0f4759-cc28-4262-823d-a621f41d77c1",                        [{"close":[243.85000610351562,243.36000061035156,245.0,242.2100067138672,242.6999969482422,236.85000610351562,234.39999389648438,233.27999877929688,237.8699951171875,228.25999450683594,229.97999572753906,222.63999938964844,223.8300018310547,223.66000366210938,222.77999877929688,229.86000061035156,238.25999450683594,239.36000061035156,237.58999633789062,236.0,228.00999450683594,232.8000030517578,232.47000122070312,233.22000122070312,227.6300048828125,227.6499938964
# ...

# %%
df
# Out:
#                           symbol        open        high         low  \
# ts
# 2025-01-02 05:00:00+00:00   AAPL  248.929993  249.100006  241.820099
# 2025-01-03 05:00:00+00:00   AAPL  243.360001  244.179993  241.889999
# 2025-01-06 05:00:00+00:00   AAPL  244.309998  247.330002  243.199997
# 2025-01-07 05:00:00+00:00   AAPL  242.979996  245.550003  241.350006
# 2025-01-08 05:00:00+00:00   AAPL  241.919998  243.712296  240.050003
# ...                          ...         ...         ...         ...
# 2025-10-06 04:00:00+00:00   AAPL  257.989990  259.070007  255.050003
# 2025-10-07 04:00:00+00:00   AAPL  256.804993  257.399994  255.429993
# 2025-10-08 04:00:00+00:00   AAPL  256.519989  258.519989  256.109985
# 2025-10-09 04:00:00+00:00   AAPL  257.804993  258.000000  253.139999
# 2025-10-10 04:00:00+00:00   AAPL  254.940002  256.380005  244.000000
#
#                                 close      volume       date  scaleFactor
# ts
# ...
